# %%
from qiskit import IBMQ

IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')

from qiskit import BasicAer
from qiskit.tools.visualization import plot_histogram

backend = BasicAer.get_backend('qasm_simulator')

# %matplotlib inline
# Out:
# ibmqfactory.load_account:WARNING:2020-10-09 10:26:28,564: Credentials are already in use. The existing account in the session will be replaced.

# %%
from byskit import byskit,gen_random_weights

# %%
n_parent = 3
n_child = 3
parents,children = gen_random_weights(n_parent,n_child)
b = byskit(backend,parents,children)
b.circ.draw(output='mpl')

# %%
results = b.execute_circ()
plot_histogram(results.results().get_counts(b.circ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0af2617e1d01> in <module>
#       1 results = b.execute_circ()
# ----> 2 plot_histogram(results.results().get_counts(b.circ))
#
# AttributeError: 'BasicAerJob' object has no attribute 'results'

# %%
n_parent = 2
n_child = 4
parents,children = gen_random_weights(n_parent,n_child)
b = byskit(backend,parents,children)
b.circ.draw(output='mpl')

# %%
results = b.execute_circ()
plot_histogram(results.results().get_counts(b.circ))
