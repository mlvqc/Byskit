# %%
from qiskit import IBMQ

IBMQ.load_account()
# provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
provider = IBMQ.get_provider(hub='ibm-q-oxford', group='on-boarding', project='on-boarding-proj')
from qiskit import BasicAer
backend = BasicAer.get_backend('unitary_simulator')

# %matplotlib inline
# Out:
# /home/sebastian/anaconda/envs/Quiskit/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
from byskit import byskit,gen_random_weights

# %%
n_parent = 3
n_child = 3
parents,children = gen_random_weights(n_parent,n_child)
b = byskit(backend,parents,children)
b.circ.draw(output='mpl')

# %%
results = b.execute_circ()
plot_histogram(results.get_counts(b.circ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-58b9971a7cc4> in <module>
# ----> 1 results = b.execute_circ()
#       2 plot_histogram(results.get_counts(b.circ))
#
# ~/Documents/simulation/Quiskit/Hackathon/Byskit/byskit.py in execute_circ(self)
#      72         self.circ.measure_all()
#      73         job = execute(self.circ, self.backend, shots=4321)
# ---> 74         return job.results
#      75
#      76 def gen_random_weights(n_parent,n_child):
#
# AttributeError: 'BasicAerJob' object has no attribute 'results'

# %%
n_parent = 2
n_child = 4
parents,children = gen_random_weights(n_parent,n_child)
b = byskit(backend,parents,children)
b.circ.draw(output='mpl')

# %%
results = b.execute_circ()
plot_histogram(results.get_counts(b.circ))
